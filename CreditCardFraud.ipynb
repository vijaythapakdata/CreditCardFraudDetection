# %% [markdown]
# <a href="https://colab.research.google.com/github/vijaythapakdata/CreditCardFraudDetection/blob/main/CreditCardFraud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Dependecies

# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Data Collection

# %%
creadit_card_data=pd.read_csv("/content/creditcard.csv")

# %%
#print first 5 rows
creadit_card_data.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
#print last five rows
creadit_card_data.tail()
# Out:
#             Time         V1         V2  ...       V28  Amount  Class
# 284802  172786.0 -11.881118  10.071785  ...  0.823731    0.77      0
# 284803  172787.0  -0.732789  -0.055080  ... -0.053527   24.79      0
# 284804  172788.0   1.919565  -0.301254  ... -0.026561   67.88      0
# 284805  172788.0  -0.240440   0.530483  ...  0.104533   10.00      0
# 284806  172792.0  -0.533413  -0.189733  ...  0.013649  217.00      0
#
# [5 rows x 31 columns]

# %%
#check the info 
creadit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
creadit_card_data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
#now check for missing values
creadit_card_data.isnull().any()
# Out:
# Time      False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17       False
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27       False
# V28       False
# Amount    False
# Class     False
# dtype: bool

# %%
creadit_card_data["Class"].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# 1-> Fraudlent transaction
#
# 0-> Normal transaction

# %%
legit=creadit_card_data[creadit_card_data.Class==0]
fraud=creadit_card_data[creadit_card_data.Class==1]

# %%
legit.shape
# Out:
# (284315, 31)

# %%
fraud.shape
# Out:
# (492, 31)

# %%
#print some statstics function for amount
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
#comapre the value for both transaction
creadit_card_data.groupby("Class").mean()
# Out:
#                Time        V1        V2  ...       V27       V28      Amount
# Class                                    ...
# 0      94838.202258  0.008258 -0.006271  ... -0.000295 -0.000131   88.291022
# 1      80746.806911 -4.771948  3.623778  ...  0.170575  0.075667  122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# Under-Sampling
#
# Build a sample dataset containing similar distribution of normal transactions and Fraudulent Transactions

# %% [markdown]
# Number of Fradulent transaction 492

# %%
legit_sample=legit.sample(n=492)

# %%
new_dataset=pd.concat([legit_sample,fraud],axis=0)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2  ...       V28  Amount  Class
# 201729  134013.0 -0.694963  1.646909  ...  0.102549    0.31      0
# 243973  152154.0  1.950818 -0.667832  ... -0.043070   56.00      0
# 227692  145177.0  2.065617 -0.042789  ... -0.061613    1.29      0
# 251034  155179.0  2.021821 -0.295815  ... -0.072096    4.00      0
# 76445    56574.0  1.253444  0.132207  ...  0.005656   27.83      0
#
# [5 rows x 31 columns]

# %%
new_dataset.tail()
# Out:
#             Time        V1        V2  ...       V28  Amount  Class
# 279863  169142.0 -1.927883  1.125653  ...  0.147968  390.00      1
# 280143  169347.0  1.378559  1.289381  ...  0.186637    0.76      1
# 280149  169351.0 -0.676143  1.126366  ...  0.194361   77.89      1
# 281144  169966.0 -3.113832  0.585864  ... -0.253700  245.00      1
# 281674  170348.0  1.991976  0.158476  ... -0.015309   42.53      1
#
# [5 rows x 31 columns]

# %%
new_dataset["Class"].value_counts()
# Out:
# 1    492
# 0    492
# Name: Class, dtype: int64

# %%
X=new_dataset.drop(columns="Class",axis=1)
Y=new_dataset["Class"]

# %%
print(X)
# Out:
#             Time        V1        V2  ...       V27       V28  Amount
# 201729  134013.0 -0.694963  1.646909  ...  0.319584  0.102549    0.31
# 243973  152154.0  1.950818 -0.667832  ... -0.066884 -0.043070   56.00
# 227692  145177.0  2.065617 -0.042789  ... -0.065970 -0.061613    1.29
# 251034  155179.0  2.021821 -0.295815  ... -0.108568 -0.072096    4.00
# 76445    56574.0  1.253444  0.132207  ... -0.075323  0.005656   27.83
# ...          ...       ...       ...  ...       ...       ...     ...
# 279863  169142.0 -1.927883  1.125653  ...  0.292680  0.147968  390.00
# 280143  169347.0  1.378559  1.289381  ...  0.389152  0.186637    0.76
# 280149  169351.0 -0.676143  1.126366  ...  0.385107  0.194361   77.89
# 281144  169966.0 -3.113832  0.585864  ...  0.884876 -0.253700  245.00
# 281674  170348.0  1.991976  0.158476  ...  0.002988 -0.015309   42.53
#
# [984 rows x 30 columns]

# %%
print(Y)
# Out:
# 201729    0
# 243973    0
# 227692    0
# 251034    0
# 76445     0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
#train and split the data
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (787, 30) (197, 30) (787,) (197,)

# %%
#fit the model
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# Model Evaluation

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# Find Accuracy Score for training data

# %%
x_training_prediction=model.predict(x_train)

x_train_accuracy=accuracy_score(x_training_prediction,y_train)

# %%
print("The accuracy score of the training data is ", x_train_accuracy)
# Out:
# The accuracy score of the training data is  0.9453621346886912

# %% [markdown]
# Calculate the accuracy Score of Test data

# %%
x_test_prediction=model.predict(x_test)

x_test_accuracy=accuracy_score(x_test_prediction,y_test)

# %%
print("The accuracy score of the test data is ", x_test_accuracy)
# Out:
# The accuracy score of the test data is  0.9390862944162437

# %% [markdown]
# Check the correlation

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Plot Heatmap

# %%
correlation=creadit_card_data.corr()

# %%
correlation
# Out:
#             Time            V1            V2  ...           V28    Amount     Class
# Time    1.000000  1.173963e-01 -1.059333e-02  ... -9.412688e-03 -0.010596 -0.012323
# V1      0.117396  1.000000e+00  4.697350e-17  ...  9.820892e-16 -0.227709 -0.101347
# V2     -0.010593  4.697350e-17  1.000000e+00  ... -3.676415e-16 -0.531409  0.091289
# V3     -0.419618 -1.424390e-15  2.512175e-16  ...  7.726948e-16 -0.210880 -0.192961
# V4     -0.105260  1.755316e-17 -1.126388e-16  ... -5.863664e-17  0.098732  0.133447
# V5      0.173072  6.391162e-17 -2.039868e-16  ... -3.299167e-16 -0.386356 -0.094974
# V6     -0.063016  2.398071e-16  5.024680e-16  ...  4.813155e-16  0.215981 -0.043643
# V7      0.084714  1.991550e-15  3.966486e-16  ... -6.836764e-17  0.397311 -0.187257
# V8     -0.036949 -9.490675e-17 -4.413984e-17  ... -4.484325e-16 -0.103079  0.019875
# V9     -0.008660  2.169581e-16 -5.728718e-17  ...  9.146779e-16 -0.044246 -0.097733
# ...

# %%
plt.figure(figsize=(15,15))

sns.heatmap(correlation,cbar=True, square=True, annot=True, annot_kws={"size":10}, fmt=".1f", cmap="Blues")
plt.show()
